# %%
import csv
import pandas as  pd

# %%
df = pd.read_csv("/home/hjiang/Resilism/processed_data/FIInfo.csv")

# %%
#index_temp = ['fiindex', 'fi_opcode', 'crash', 'benign', 'SDC']
df_temp = df[df["fi_opcode"] == 'phi']
df_temp = df_temp.sort_values("fiindex")
print(df_temp)
ax = df_temp.plot.bar(stacked=True, x = 'fiindex', title = "Error types across phi instructions")
# Out:
#      fiindex fi_opcode     crash    benign           SDC
# 324      402       phi  0.900000  0.033333  6.666667e-02
# 536     1017       phi  0.900000  0.033333  6.666667e-02
# 61      3119       phi  0.766667  0.133333  1.000000e-01
# 133     3154       phi  0.900000  0.066667  3.333333e-02
# 140     3166       phi  0.866667  0.100000  3.333333e-02
# 147     3176       phi  0.866667  0.100000  3.333333e-02
# 80      3197       phi  0.833333  0.066667  1.000000e-01
# 110     3243       phi  0.900000  0.033333  6.666667e-02
# 0       4656       phi  0.900000  0.100000  0.000000e+00
# 12      4700       phi  0.866667  0.133333  0.000000e+00
# 37      5898       phi  0.966667  0.033333  0.000000e+00
# 52      5923       phi  0.966667  0.000000  3.333333e-02
# 163     7846       phi  0.966667  0.033333  0.000000e+00
# 154     7856       phi  0.866667  0.133333  0.000000e+00
# 155     7857       phi  0.766667  0.233333 -1.110223e-16
# ...

# %%
#index_temp = ['fiindex', 'fi_opcode', 'crash', 'benign', 'SDC']
df_temp = df[df["fi_opcode"] == 'icmp']
df_temp = df_temp.sort_values("fiindex")
print(df_temp)
ax = df_temp.plot.bar(stacked=True,figsize=(8,8), x = 'fiindex', title = "Error types across icmp instructions")
# Out:
#      fiindex fi_opcode     crash    benign       SDC
# 335      416      icmp  0.000000  0.000000  1.000000
# 554     1059      icmp  0.733333  0.000000  0.266667
# 79      3140      icmp  0.000000  0.166667  0.833333
# 139     3161      icmp  0.033333  0.133333  0.833333
# 146     3173      icmp  0.033333  0.266667  0.700000
# 153     3183      icmp  0.066667  0.166667  0.766667
# 109     3229      icmp  0.000000  0.066667  0.933333
# 130     3266      icmp  0.000000  0.200000  0.800000
# 11      4669      icmp  0.000000  0.433333  0.566667
# 36      4739      icmp  0.000000  0.133333  0.866667
# 51      5915      icmp  0.066667  0.433333  0.500000
# 60      5932      icmp  0.133333  0.000000  0.866667
# 167     7851      icmp  0.000000  1.000000  0.000000
# 160     7864      icmp  1.000000  0.000000  0.000000
